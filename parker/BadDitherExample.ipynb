# %%
cd /orange/adamginsburg/w51/gtc/GTC2-20AFLO/OB0001/object
# Out:
# /orange/adamginsburg/w51/gtc/GTC2-20AFLO/OB0001/object

# %%
files = !ls *fits

# %%
len(files)
# Out:
# 234

# %%
files[99]
# Out:
# '0002613884-20200712-EMIR-DITHERED_IMAGE-accum.fits'

# %%
from astropy.io import fits

# %%
filehandle = fits.open(files[99])

# %%
filehandle
# Out:
# [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x2b9267f68860>, <astropy.io.fits.hdu.image.ImageHDU object at 0x2b9267fdddd8>, <astropy.io.fits.hdu.image.ImageHDU object at 0x2b9267fe34a8>]

# %%
from astropy.wcs import WCS

# %%
filehandle[0].header
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                  -32 / number of bits per data pixel
# NAXIS   =                    2 / number of data axes
# NAXIS1  =                 2377 / length of data axis 1
# NAXIS2  =                 2383 / length of data axis 2
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# DETVER  = 'SCI     '           / 401 Detector used: science or engineering
# NSEC    =                    1 / 402 Number of sequences executed at detector
# NRST    =                    1 / 403 Number of resets
# OPTRST  =                    3 / 404 Type of reset
# NIMGRST =                    1 / 405 Number of reset images
# NRDBL_ND=                    0 / 406 Number of non-productive reads before loop
# NRDBL   =                    0 / 407 Number of productive reads before loop
# NLOOP   =                    1 / 408 Exposure Number
# TOPER   =                  559 / 409 Time period in the detector sequence formul
# NRDIL_ND=                    8 / 410 Number of non-productibe reads per loop ite
# NRDIL   =                    1 / 411 Number of productive reads per loop iterati
# Y_SIZE  =                 1024 / 412 Offset in pixels for window mode
# Y_SIZE_B=                    0 / 413 Number of readable columns (1024 - Y_SIZE)
# NPARAM_X=                    0 / 414 Number of dummy readouts of a line
# GAIN    =                  3.3 / 416 Gain, in e-/ADU
# RON     =                  6.2 / 417 Read-out noise, in ADU
# VOFFSET =                   0. / 418 Voff
# VRESET  =                   0. / 419 Vreset
# WINMODE =                    0 / 420 Window mode: full, 128px
# BIASGATE=                   0. / 421 Biasgate
# FIRMVER = '20023   '           / 422 Controller firmware version
# NFRSEC  =                    2 / 423 Frames produced per detector exposure
# FRSEC   =                    0 / 424 Counter of the frame sequence
# NEXP    =                    1 / 425 Number of detector exposures
# EXP     =                    0 / 426 Detector exposures counter
# TSTAMP  =           1594612398 / Time stamp in UTC
# READMODN=                    1 / E00 Readout (numerico) mode used for the observ
# TSUTC1  =      1594612397.6684 / E01 Time stamp before read detector (UTC)
# TSUTC2  =     1594613630.29459 / E02 Time stamp after read detector (UTC)
# TSUTCD  =     11.1068141460419 / E03 Diff. between TSUTC2 and TSUTC1
# ITER_NUM=                    1 / E04 frame counter
# FRSTAT  =                    2 / E05 status 0=START,1=RUN,2=END,3=ABR,4=ERR
# APPNAME = '/work/gcsop/etc/config/emir/lods/33-18_SDSU2_MUX_v20_UNIX.lod' / E06
# WINDCOV =                    1 / Window blind status (OPEN/CLOSE)
# WINDOW  =                    1 / Window status (OPEN/CLOSE)
# XDTU_C  =      -999.9990234375 / X Absolute position commanded to DTU. If not -9
# YDTU_C  =      -999.9990234375 / Y Absolute position commanded to DTU. If not -9
# ZDTU_C  =      -999.9990234375 / Z Absolute position commanded to DTU. If not -9
# XDTU_F  =             0.922918 / DTU-X Scale Factor
# YDTU_F  =             0.971815 / DTU-Y Scale Factor
# ZDTU_F  =                   1. / DTU-Z Scale Factor
# CSUP1   =    0.488999992609024 / CSU current position
# CSUP2   =    0.492000013589859 / CSU current position
# CSUP3   =    0.495000004768372 / CSU current position
# CSUP4   =    0.493999987840652 / CSU current position
# CSUP5   =    0.493000000715256 / CSU current position
# CSUP6   =    0.493000000715256 / CSU current position
# CSUP7   =    0.492000013589859 / CSU current position
# CSUP8   =    0.495999991893768 / CSU current position
# CSUP9   =     0.49099999666214 / CSU current position
# CSUP10  =    0.495000004768372 / CSU current position
# CSUP11  =    0.492000013589859 / CSU current position
# CSUP12  =    0.508000016212463 / CSU current position
# CSUP13  =    0.493000000715256 / CSU current position
# CSUP14  =    0.493000000715256 / CSU current position
# CSUP15  =    0.490000009536743 / CSU current position
# CSUP16  =    0.493000000715256 / CSU current position
# CSUP17  =    0.497000008821487 / CSU current position
# CSUP18  =    0.493000000715256 / CSU current position
# CSUP19  =    0.493000000715256 / CSU current position
# CSUP20  =    0.493000000715256 / CSU current position
# CSUP21  =     0.49099999666214 / CSU current position
# CSUP22  =    0.493000000715256 / CSU current position
# CSUP23  =    0.493000000715256 / CSU current position
# CSUP24  =    0.492000013589859 / CSU current position
# CSUP25  =     0.49099999666214 / CSU current position
# CSUP26  =     0.49099999666214 / CSU current position
# CSUP27  =    0.493000000715256 / CSU current position
# CSUP28  =    0.493999987840652 / CSU current position
# CSUP29  =    0.492000013589859 / CSU current position
# CSUP30  =    0.493000000715256 / CSU current position
# CSUP31  =     0.49099999666214 / CSU current position
# CSUP32  =    0.495000004768372 / CSU current position
# CSUP33  =    0.493000000715256 / CSU current position
# CSUP34  =    0.493999987840652 / CSU current position
# CSUP35  =     0.49099999666214 / CSU current position
# CSUP36  =     0.49099999666214 / CSU current position
# CSUP37  =    0.492000013589859 / CSU current position
# CSUP38  =    0.493000000715256 / CSU current position
# CSUP39  =    0.493000000715256 / CSU current position
# CSUP40  =     0.49099999666214 / CSU current position
# CSUP41  =     0.49099999666214 / CSU current position
# CSUP42  =    0.493999987840652 / CSU current position
# CSUP43  =    0.493000000715256 / CSU current position
# CSUP44  =    0.493999987840652 / CSU current position
# CSUP45  =    0.493000000715256 / CSU current position
# CSUP46  =    0.493000000715256 / CSU current position
# CSUP47  =    0.493000000715256 / CSU current position
# CSUP48  =    0.497000008821487 / CSU current position
# CSUP49  =    0.493000000715256 / CSU current position
# CSUP50  =    0.493999987840652 / CSU current position
# CSUP51  =    0.493000000715256 / CSU current position
# CSUP52  =    0.492000013589859 / CSU current position
# CSUP53  =    0.493999987840652 / CSU current position
# CSUP54  =    0.493999987840652 / CSU current position
# CSUP55  =    0.493000000715256 / CSU current position
# CSUP56  =     0.49099999666214 / CSU current position
# CSUP57  =    0.493000000715256 / CSU current position
# CSUP58  =    0.492000013589859 / CSU current position
# CSUP59  =    0.493000000715256 / CSU current position
# CSUP60  =    0.492000013589859 / CSU current position
# CSUP61  =    0.493999987840652 / CSU current position
# CSUP62  =    0.493000000715256 / CSU current position
# CSUP63  =    0.493000000715256 / CSU current position
# CSUP64  =    0.492000013589859 / CSU current position
# CSUP65  =    0.493000000715256 / CSU current position
# CSUP66  =    0.492000013589859 / CSU current position
# CSUP67  =    0.493000000715256 / CSU current position
# CSUP68  =    0.488999992609024 / CSU current position
# CSUP69  =    0.507000029087067 / CSU current position
# CSUP70  =    0.490000009536743 / CSU current position
# CSUP71  =    0.493000000715256 / CSU current position
# CSUP72  =    0.493000000715256 / CSU current position
# CSUP73  =    0.492000013589859 / CSU current position
# CSUP74  =    0.488999992609024 / CSU current position
# CSUP75  =    0.493000000715256 / CSU current position
# CSUP76  =    0.490000009536743 / CSU current position
# CSUP77  =    0.495999991893768 / CSU current position
# CSUP78  =     0.49099999666214 / CSU current position
# CSUP79  =    0.493000000715256 / CSU current position
# CSUP80  =    0.493000000715256 / CSU current position
# CSUP81  =    0.495000004768372 / CSU current position
# CSUP82  =    0.488000005483627 / CSU current position
# CSUP83  =    0.493999987840652 / CSU current position
# CSUP84  =    0.492000013589859 / CSU current position
# CSUP85  =     0.50900000333786 / CSU current position
# CSUP86  =     0.49099999666214 / CSU current position
# CSUP87  =    0.495999991893768 / CSU current position
# CSUP88  =    0.492000013589859 / CSU current position
# CSUP89  =    0.493000000715256 / CSU current position
# CSUP90  =    0.488999992609024 / CSU current position
# CSUP91  =    0.493999987840652 / CSU current position
# CSUP92  =    0.488999992609024 / CSU current position
# CSUP93  =    0.493000000715256 / CSU current position
# CSUP94  =    0.493000000715256 / CSU current position
# CSUP95  =    0.493000000715256 / CSU current position
# CSUP96  =    0.492000013589859 / CSU current position
# CSUP97  =    0.497000008821487 / CSU current position
# CSUP98  =    0.492000013589859 / CSU current position
# CSUP99  =    0.493999987840652 / CSU current position
# CSUP100 =    0.490000009536743 / CSU current position
# CSUP101 =    0.493999987840652 / CSU current position
# CSUP102 =    0.490000009536743 / CSU current position
# CSUP103 =    0.493999987840652 / CSU current position
# CSUP104 =    0.492000013589859 / CSU current position
# CSUP105 =    0.495000004768372 / CSU current position
# CSUP106 =    0.493000000715256 / CSU current position
# CSUP107 =    0.492000013589859 / CSU current position
# CSUP108 =    0.492000013589859 / CSU current position
# CSUP109 =    0.493000000715256 / CSU current position
# CSUP110 =    0.490000009536743 / CSU current position
# CS_0    =               10000. / CSU bars sensors
# CS_1    =               10000. / CSU bars sensors
# CS_2    =               10000. / CSU bars sensors
# CS_3    =               10000. / CSU bars sensors
# CS_4    =               10000. / CSU bars sensors
# CS_5    =               10000. / CSU bars sensors
# CS_6    =               10000. / CSU bars sensors
# CS_7    =               10000. / CSU bars sensors
# CS_8    =               10000. / CSU bars sensors
# CS_9    =               10000. / CSU bars sensors
# CS_10   =               10000. / CSU bars sensors
# CS_11   =               10000. / CSU bars sensors
# CS_12   =               10000. / CSU bars sensors
# CS_13   =               10000. / CSU bars sensors
# CS_14   =               10000. / CSU bars sensors
# CS_15   =               10000. / CSU bars sensors
# CS_16   =               10000. / CSU bars sensors
# CS_17   =               10000. / CSU bars sensors
# CS_18   =               10000. / CSU bars sensors
# CS_19   =               10000. / CSU bars sensors
# CS_20   =               10000. / CSU bars sensors
# CS_21   =               10000. / CSU bars sensors
# CS_22   =               10000. / CSU bars sensors
# CS_23   =               10000. / CSU bars sensors
# CS_24   =               10000. / CSU bars sensors
# CS_25   =               10000. / CSU bars sensors
# CS_26   =               10000. / CSU bars sensors
# CS_27   =               10000. / CSU bars sensors
# CS_28   =               10000. / CSU bars sensors
# CS_29   =               10000. / CSU bars sensors
# CS_30   =               10000. / CSU bars sensors
# CS_31   =               10000. / CSU bars sensors
# CS_32   =               10000. / CSU bars sensors
# CS_33   =               10000. / CSU bars sensors
# CS_34   =               10000. / CSU bars sensors
# CS_35   =               10000. / CSU bars sensors
# CS_36   =               10000. / CSU bars sensors
# CS_37   =               10000. / CSU bars sensors
# CS_38   =               10000. / CSU bars sensors
# CS_39   =               10000. / CSU bars sensors
# CS_40   =               10000. / CSU bars sensors
# CS_41   =               10000. / CSU bars sensors
# CS_42   =               10000. / CSU bars sensors
# CS_43   =               10000. / CSU bars sensors
# CS_44   =               10000. / CSU bars sensors
# CS_45   =               10000. / CSU bars sensors
# CS_46   =               10000. / CSU bars sensors
# CS_47   =               10000. / CSU bars sensors
# CS_48   =               10000. / CSU bars sensors
# CS_49   =               10000. / CSU bars sensors
# CS_50   =               10000. / CSU bars sensors
# CS_51   =               10000. / CSU bars sensors
# CS_52   =               10000. / CSU bars sensors
# CS_53   =               10000. / CSU bars sensors
# CS_54   =               10000. / CSU bars sensors
# CS_55   =               10000. / CSU bars sensors
# CS_56   =               10000. / CSU bars sensors
# CS_57   =               10000. / CSU bars sensors
# CS_58   =               10000. / CSU bars sensors
# CS_59   =               10000. / CSU bars sensors
# CS_60   =               10000. / CSU bars sensors
# CS_61   =               10000. / CSU bars sensors
# CS_62   =               10000. / CSU bars sensors
# CS_63   =               10000. / CSU bars sensors
# CS_64   =               10000. / CSU bars sensors
# CS_65   =               10000. / CSU bars sensors
# CS_66   =               10000. / CSU bars sensors
# CS_67   =               10000. / CSU bars sensors
# CS_68   =               10000. / CSU bars sensors
# CS_69   =               10000. / CSU bars sensors
# CS_70   =               10000. / CSU bars sensors
# CS_71   =               10000. / CSU bars sensors
# CS_72   =               10000. / CSU bars sensors
# CS_73   =               10000. / CSU bars sensors
# CS_74   =               10000. / CSU bars sensors
# CS_75   =               10000. / CSU bars sensors
# CS_76   =               10000. / CSU bars sensors
# CS_77   =               10000. / CSU bars sensors
# CS_78   =               10000. / CSU bars sensors
# CS_79   =               10000. / CSU bars sensors
# CS_80   =               10000. / CSU bars sensors
# CS_81   =               10000. / CSU bars sensors
# CS_82   =               10000. / CSU bars sensors
# CS_83   =               10000. / CSU bars sensors
# CS_84   =               10000. / CSU bars sensors
# CS_85   =               10000. / CSU bars sensors
# CS_86   =               10000. / CSU bars sensors
# CS_87   =               10000. / CSU bars sensors
# CS_88   =               10000. / CSU bars sensors
# CS_89   =               10000. / CSU bars sensors
# CS_90   =               10000. / CSU bars sensors
# CS_91   =               10000. / CSU bars sensors
# CS_92   =               10000. / CSU bars sensors
# CS_93   =               10000. / CSU bars sensors
# CS_94   =               10000. / CSU bars sensors
# CS_95   =               10000. / CSU bars sensors
# CS_96   =               10000. / CSU bars sensors
# CS_97   =               10000. / CSU bars sensors
# CS_98   =               10000. / CSU bars sensors
# CS_99   =               10000. / CSU bars sensors
# CS_100  =               10000. / CSU bars sensors
# CS_101  =               10000. / CSU bars sensors
# CS_102  =               10000. / CSU bars sensors
# CS_103  =               10000. / CSU bars sensors
# CS_104  =               10000. / CSU bars sensors
# CS_105  =               10000. / CSU bars sensors
# CS_106  =               10000. / CSU bars sensors
# CS_107  =               10000. / CSU bars sensors
# CS_108  =               10000. / CSU bars sensors
# CS_109  =               10000. / CSU bars sensors
# CS_110  =               10000. / CSU bars sensors
# CS_111  =               10000. / CSU bars sensors
# CS_112  =               10000. / CSU bars sensors
# CS_113  =               10000. / CSU bars sensors
# CS_114  =               10000. / CSU bars sensors
# CS_115  =               10000. / CSU bars sensors
# CS_116  =               10000. / CSU bars sensors
# CS_117  =               10000. / CSU bars sensors
# CS_118  =               10000. / CSU bars sensors
# CS_119  =               10000. / CSU bars sensors
# CS_120  =               10000. / CSU bars sensors
# CS_121  =               10000. / CSU bars sensors
# CS_122  =               10000. / CSU bars sensors
# CS_123  =               10000. / CSU bars sensors
# CS_124  =               10000. / CSU bars sensors
# CS_125  =               10000. / CSU bars sensors
# CS_126  =               10000. / CSU bars sensors
# CS_127  =               10000. / CSU bars sensors
# CS_128  =               10000. / CSU bars sensors
# CS_129  =               10000. / CSU bars sensors
# CS_130  =               10000. / CSU bars sensors
# CS_131  =               10000. / CSU bars sensors
# CS_132  =               10000. / CSU bars sensors
# CS_133  =               10000. / CSU bars sensors
# CS_134  =               10000. / CSU bars sensors
# CS_135  =               10000. / CSU bars sensors
# CS_136  =               10000. / CSU bars sensors
# CS_137  =               10000. / CSU bars sensors
# CS_138  =               10000. / CSU bars sensors
# CS_139  =               10000. / CSU bars sensors
# CS_140  =               10000. / CSU bars sensors
# CS_141  =               10000. / CSU bars sensors
# CS_142  =               10000. / CSU bars sensors
# CS_143  =               10000. / CSU bars sensors
# CS_144  =               10000. / CSU bars sensors
# CS_145  =               10000. / CSU bars sensors
# CS_146  =               10000. / CSU bars sensors
# CS_147  =               10000. / CSU bars sensors
# CS_148  =               10000. / CSU bars sensors
# CS_149  =               10000. / CSU bars sensors
# CS_150  =               10000. / CSU bars sensors
# CS_151  =               10000. / CSU bars sensors
# CS_152  =               10000. / CSU bars sensors
# CS_153  =               10000. / CSU bars sensors
# CS_154  =               10000. / CSU bars sensors
# CS_155  =               10000. / CSU bars sensors
# CS_156  =               10000. / CSU bars sensors
# CS_157  =               10000. / CSU bars sensors
# CS_158  =               10000. / CSU bars sensors
# CS_159  =               10000. / CSU bars sensors
# CS_160  =               10000. / CSU bars sensors
# CS_161  =               10000. / CSU bars sensors
# CS_162  =               10000. / CSU bars sensors
# CS_163  =               10000. / CSU bars sensors
# CS_164  =               10000. / CSU bars sensors
# CS_165  =               10000. / CSU bars sensors
# CS_166  =               10000. / CSU bars sensors
# CS_167  =               10000. / CSU bars sensors
# CS_168  =               10000. / CSU bars sensors
# CS_169  =               10000. / CSU bars sensors
# CS_170  =               10000. / CSU bars sensors
# CS_171  =               10000. / CSU bars sensors
# CS_172  =               10000. / CSU bars sensors
# CS_173  =               10000. / CSU bars sensors
# CS_174  =               10000. / CSU bars sensors
# CS_175  =               10000. / CSU bars sensors
# CS_176  =               10000. / CSU bars sensors
# CS_177  =               10000. / CSU bars sensors
# CS_178  =               10000. / CSU bars sensors
# CS_179  =               10000. / CSU bars sensors
# CS_180  =               10000. / CSU bars sensors
# CS_181  =               10000. / CSU bars sensors
# CS_182  =               10000. / CSU bars sensors
# CS_183  =               10000. / CSU bars sensors
# CS_184  =               10000. / CSU bars sensors
# CS_185  =               10000. / CSU bars sensors
# CS_186  =               10000. / CSU bars sensors
# CS_187  =               10000. / CSU bars sensors
# CS_188  =               10000. / CSU bars sensors
# CS_189  =               10000. / CSU bars sensors
# CS_190  =               10000. / CSU bars sensors
# CS_191  =               10000. / CSU bars sensors
# CS_192  =               10000. / CSU bars sensors
# CS_193  =               10000. / CSU bars sensors
# CS_194  =               10000. / CSU bars sensors
# CS_195  =               10000. / CSU bars sensors
# CS_196  =               10000. / CSU bars sensors
# CS_197  =               10000. / CSU bars sensors
# CS_198  =               10000. / CSU bars sensors
# CS_199  =               10000. / CSU bars sensors
# CS_200  =               10000. / CSU bars sensors
# CS_201  =               10000. / CSU bars sensors
# CS_202  =               10000. / CSU bars sensors
# CS_203  =               10000. / CSU bars sensors
# CS_204  =               10000. / CSU bars sensors
# CS_205  =               10000. / CSU bars sensors
# CS_206  =               10000. / CSU bars sensors
# CS_207  =               10000. / CSU bars sensors
# CS_208  =               10000. / CSU bars sensors
# CS_209  =               10000. / CSU bars sensors
# CS_210  =               10000. / CSU bars sensors
# CS_211  =               10000. / CSU bars sensors
# CS_212  =               10000. / CSU bars sensors
# CS_213  =               10000. / CSU bars sensors
# CS_214  =               10000. / CSU bars sensors
# CS_215  =               10000. / CSU bars sensors
# CS_216  =               10000. / CSU bars sensors
# CS_217  =               10000. / CSU bars sensors
# CS_218  =               10000. / CSU bars sensors
# CS_219  =               10000. / CSU bars sensors
# CS_220  =               10000. / CSU bars sensors
# CS_221  =               10000. / CSU bars sensors
# CS_222  =               10000. / CSU bars sensors
# CS_223  =               10000. / CSU bars sensors
# CS_224  =               10000. / CSU bars sensors
# CS_225  =               10000. / CSU bars sensors
# CS_226  =               10000. / CSU bars sensors
# CS_227  =               10000. / CSU bars sensors
# CS_228  =               10000. / CSU bars sensors
# CS_229  =               10000. / CSU bars sensors
# CS_230  =               10000. / CSU bars sensors
# CS_231  =               10000. / CSU bars sensors
# CS_232  =               10000. / CSU bars sensors
# CS_233  =               10000. / CSU bars sensors
# CS_234  =               10000. / CSU bars sensors
# CS_235  =               10000. / CSU bars sensors
# CS_236  =               10000. / CSU bars sensors
# CS_237  =               10000. / CSU bars sensors
# CS_238  =               10000. / CSU bars sensors
# CS_239  =               10000. / CSU bars sensors
# CS_240  =               10000. / CSU bars sensors
# CS_241  =               10000. / CSU bars sensors
# CS_242  =               10000. / CSU bars sensors
# CS_243  =               10000. / CSU bars sensors
# CS_244  =               10000. / CSU bars sensors
# CS_245  =               10000. / CSU bars sensors
# CS_246  =               10000. / CSU bars sensors
# CS_247  =               10000. / CSU bars sensors
# CS_248  =               10000. / CSU bars sensors
# CS_249  =               10000. / CSU bars sensors
# CS_250  =               10000. / CSU bars sensors
# CS_251  =               10000. / CSU bars sensors
# CS_252  =               10000. / CSU bars sensors
# CS_253  =               10000. / CSU bars sensors
# CS_254  =               10000. / CSU bars sensors
# CS_255  =               10000. / CSU bars sensors
# CS_256  =               10000. / CSU bars sensors
# CS_257  =               10000. / CSU bars sensors
# CS_258  =               10000. / CSU bars sensors
# CS_259  =               10000. / CSU bars sensors
# CS_260  =               10000. / CSU bars sensors
# CS_261  =               10000. / CSU bars sensors
# CS_262  =               10000. / CSU bars sensors
# CS_263  =               10000. / CSU bars sensors
# CS_264  =               10000. / CSU bars sensors
# CS_265  =               10000. / CSU bars sensors
# CS_266  =               10000. / CSU bars sensors
# CS_267  =               10000. / CSU bars sensors
# CS_268  =               10000. / CSU bars sensors
# CS_269  =               10000. / CSU bars sensors
# CS_270  =               10000. / CSU bars sensors
# CS_271  =               10000. / CSU bars sensors
# CS_272  =               10000. / CSU bars sensors
# CS_273  =               10000. / CSU bars sensors
# CS_274  =               10000. / CSU bars sensors
# CS_275  =               10000. / CSU bars sensors
# CS_276  =               10000. / CSU bars sensors
# CS_277  =               10000. / CSU bars sensors
# CS_278  =               10000. / CSU bars sensors
# CS_279  =               10000. / CSU bars sensors
# CS_280  =               10000. / CSU bars sensors
# CS_281  =               10000. / CSU bars sensors
# CS_282  =               10000. / CSU bars sensors
# CS_283  =               10000. / CSU bars sensors
# CS_284  =               10000. / CSU bars sensors
# CS_285  =               10000. / CSU bars sensors
# CS_286  =               10000. / CSU bars sensors
# CS_287  =               10000. / CSU bars sensors
# CS_288  =               10000. / CSU bars sensors
# CS_289  =               10000. / CSU bars sensors
# CS_290  =               10000. / CSU bars sensors
# CS_291  =               10000. / CSU bars sensors
# CS_292  =               10000. / CSU bars sensors
# CS_293  =               10000. / CSU bars sensors
# CS_294  =               10000. / CSU bars sensors
# CS_295  =               10000. / CSU bars sensors
# CS_296  =               10000. / CSU bars sensors
# CS_297  =               10000. / CSU bars sensors
# CS_298  =               10000. / CSU bars sensors
# CS_299  =               10000. / CSU bars sensors
# CS_300  =               10000. / CSU bars sensors
# CS_301  =               10000. / CSU bars sensors
# CS_302  =               10000. / CSU bars sensors
# CS_303  =               10000. / CSU bars sensors
# CS_304  =               10000. / CSU bars sensors
# CS_305  =               10000. / CSU bars sensors
# CS_306  =               10000. / CSU bars sensors
# CS_307  =               10000. / CSU bars sensors
# CS_308  =               10000. / CSU bars sensors
# CS_309  =               10000. / CSU bars sensors
# CS_310  =               10000. / CSU bars sensors
# CS_311  =               10000. / CSU bars sensors
# CS_312  =               10000. / CSU bars sensors
# CS_313  =               10000. / CSU bars sensors
# CS_314  =               10000. / CSU bars sensors
# CS_315  =               10000. / CSU bars sensors
# CS_316  =               10000. / CSU bars sensors
# CS_317  =               10000. / CSU bars sensors
# CS_318  =               10000. / CSU bars sensors
# CS_319  =               10000. / CSU bars sensors
# CS_320  =               10000. / CSU bars sensors
# CS_321  =               10000. / CSU bars sensors
# CS_322  =               10000. / CSU bars sensors
# CS_323  =               10000. / CSU bars sensors
# CS_324  =               10000. / CSU bars sensors
# CS_325  =               10000. / CSU bars sensors
# CS_326  =               10000. / CSU bars sensors
# CS_327  =               10000. / CSU bars sensors
# CS_328  =               10000. / CSU bars sensors
# CS_329  =               10000. / CSU bars sensors
# CS_330  =               10000. / CSU bars sensors
# CS_331  =               10000. / CSU bars sensors
# CS_332  =               10000. / CSU bars sensors
# CS_333  =               10000. / CSU bars sensors
# CS_334  =               10000. / CSU bars sensors
# CS_335  =               10000. / CSU bars sensors
# CS_336  =               10000. / CSU bars sensors
# CS_337  =               10000. / CSU bars sensors
# CS_338  =               10000. / CSU bars sensors
# CS_339  =               10000. / CSU bars sensors
# CS_340  =               10000. / CSU bars sensors
# CS_341  =               10000. / CSU bars sensors
# CS_342  =               10000. / CSU bars sensors
# CS_343  =               10000. / CSU bars sensors
# CS_344  =               10000. / CSU bars sensors
# CS_345  =               10000. / CSU bars sensors
# CS_346  =               10000. / CSU bars sensors
# CS_347  =               10000. / CSU bars sensors
# CS_348  =               10000. / CSU bars sensors
# CS_349  =               10000. / CSU bars sensors
# CS_350  =               10000. / CSU bars sensors
# CS_351  =               10000. / CSU bars sensors
# CS_352  =               10000. / CSU bars sensors
# CS_353  =               10000. / CSU bars sensors
# CS_354  =               10000. / CSU bars sensors
# CS_355  =               10000. / CSU bars sensors
# CS_356  =               10000. / CSU bars sensors
# CS_357  =               10000. / CSU bars sensors
# CS_358  =               10000. / CSU bars sensors
# CS_359  =               10000. / CSU bars sensors
# CS_360  =               10000. / CSU bars sensors
# CS_361  =               10000. / CSU bars sensors
# CS_362  =               10000. / CSU bars sensors
# CS_363  =               10000. / CSU bars sensors
# CS_364  =               10000. / CSU bars sensors
# CS_365  =               10000. / CSU bars sensors
# CS_366  =               10000. / CSU bars sensors
# CS_367  =               10000. / CSU bars sensors
# CS_368  =               10000. / CSU bars sensors
# CS_369  =               10000. / CSU bars sensors
# CS_370  =               10000. / CSU bars sensors
# CS_371  =               10000. / CSU bars sensors
# CS_372  =               10000. / CSU bars sensors
# CS_373  =               10000. / CSU bars sensors
# CS_374  =               10000. / CSU bars sensors
# CS_375  =               10000. / CSU bars sensors
# CS_376  =               10000. / CSU bars sensors
# CS_377  =               10000. / CSU bars sensors
# CS_378  =               10000. / CSU bars sensors
# CS_379  =               10000. / CSU bars sensors
# CS_380  =               10000. / CSU bars sensors
# CS_381  =               10000. / CSU bars sensors
# CS_382  =               10000. / CSU bars sensors
# CS_383  =               10000. / CSU bars sensors
# CS_384  =               10000. / CSU bars sensors
# CS_385  =               10000. / CSU bars sensors
# CS_386  =               10000. / CSU bars sensors
# CS_387  =               10000. / CSU bars sensors
# CS_388  =               10000. / CSU bars sensors
# CS_389  =               10000. / CSU bars sensors
# CS_390  =               10000. / CSU bars sensors
# CS_391  =               10000. / CSU bars sensors
# CS_392  =               10000. / CSU bars sensors
# CS_393  =               10000. / CSU bars sensors
# CS_394  =               10000. / CSU bars sensors
# CS_395  =               10000. / CSU bars sensors
# CS_396  =               10000. / CSU bars sensors
# CS_397  =               10000. / CSU bars sensors
# CS_398  =               10000. / CSU bars sensors
# CS_399  =               10000. / CSU bars sensors
# CS_400  =               10000. / CSU bars sensors
# CS_401  =               10000. / CSU bars sensors
# CS_402  =               10000. / CSU bars sensors
# CS_403  =               10000. / CSU bars sensors
# CS_404  =               10000. / CSU bars sensors
# CS_405  =               10000. / CSU bars sensors
# CS_406  =               10000. / CSU bars sensors
# CS_407  =               10000. / CSU bars sensors
# CS_408  =               10000. / CSU bars sensors
# CS_409  =               10000. / CSU bars sensors
# CS_410  =               10000. / CSU bars sensors
# CS_411  =               10000. / CSU bars sensors
# CS_412  =               10000. / CSU bars sensors
# CS_413  =               10000. / CSU bars sensors
# CS_414  =               10000. / CSU bars sensors
# CS_415  =               10000. / CSU bars sensors
# CS_416  =               10000. / CSU bars sensors
# CS_417  =               10000. / CSU bars sensors
# CS_418  =               10000. / CSU bars sensors
# CS_419  =               10000. / CSU bars sensors
# CS_420  =               10000. / CSU bars sensors
# CS_421  =               10000. / CSU bars sensors
# CS_422  =               10000. / CSU bars sensors
# CS_423  =               10000. / CSU bars sensors
# CS_424  =               10000. / CSU bars sensors
# CS_425  =               10000. / CSU bars sensors
# CS_426  =               10000. / CSU bars sensors
# CS_427  =               10000. / CSU bars sensors
# CS_428  =               10000. / CSU bars sensors
# CS_429  =               10000. / CSU bars sensors
# CS_430  =               10000. / CSU bars sensors
# CS_431  =               10000. / CSU bars sensors
# CS_432  =               10000. / CSU bars sensors
# ...
# OBJSL2  = '        '           / Objects assigned to slit
# COMSL2  = '        '           / Object comment in the user catalogue.
# OBJSL3  = '        '           / Objects assigned to slit
# COMSL3  = '        '           / Object comment in the user catalogue.
# OBJSL4  = '        '           / Objects assigned to slit
# COMSL4  = '        '           / Object comment in the user catalogue.
# OBJSL5  = '        '           / Objects assigned to slit
# COMSL5  = '        '           / Object comment in the user catalogue.
# OBJSL6  = '        '           / Objects assigned to slit
# COMSL6  = '        '           / Object comment in the user catalogue.
# OBJSL7  = '        '           / Objects assigned to slit
# COMSL7  = '        '           / Object comment in the user catalogue.
# OBJSL8  = '        '           / Objects assigned to slit
# COMSL8  = '        '           / Object comment in the user catalogue.
# OBJSL9  = '        '           / Objects assigned to slit
# COMSL9  = '        '           / Object comment in the user catalogue.
# OBJSL10 = '        '           / Objects assigned to slit
# COMSL10 = '        '           / Object comment in the user catalogue.
# OBJSL11 = '        '           / Objects assigned to slit
# COMSL11 = '        '           / Object comment in the user catalogue.
# OBJSL12 = '        '           / Objects assigned to slit
# COMSL12 = '        '           / Object comment in the user catalogue.
# OBJSL13 = '        '           / Objects assigned to slit
# COMSL13 = '        '           / Object comment in the user catalogue.
# OBJSL14 = '        '           / Objects assigned to slit
# COMSL14 = '        '           / Object comment in the user catalogue.
# OBJSL15 = '        '           / Objects assigned to slit
# COMSL15 = '        '           / Object comment in the user catalogue.
# OBJSL16 = '        '           / Objects assigned to slit
# COMSL16 = '        '           / Object comment in the user catalogue.
# OBJSL17 = '        '           / Objects assigned to slit
# COMSL17 = '        '           / Object comment in the user catalogue.
# OBJSL18 = '        '           / Objects assigned to slit
# COMSL18 = '        '           / Object comment in the user catalogue.
# OBJSL19 = '        '           / Objects assigned to slit
# COMSL19 = '        '           / Object comment in the user catalogue.
# OBJSL20 = '        '           / Objects assigned to slit
# COMSL20 = '        '           / Object comment in the user catalogue.
# OBJSL21 = '        '           / Objects assigned to slit
# COMSL21 = '        '           / Object comment in the user catalogue.
# OBJSL22 = '        '           / Objects assigned to slit
# COMSL22 = '        '           / Object comment in the user catalogue.
# OBJSL23 = '        '           / Objects assigned to slit
# COMSL23 = '        '           / Object comment in the user catalogue.
# OBJSL24 = '        '           / Objects assigned to slit
# COMSL24 = '        '           / Object comment in the user catalogue.
# OBJSL25 = '        '           / Objects assigned to slit
# COMSL25 = '        '           / Object comment in the user catalogue.
# OBJSL26 = '        '           / Objects assigned to slit
# COMSL26 = '        '           / Object comment in the user catalogue.
# OBJSL27 = '        '           / Objects assigned to slit
# COMSL27 = '        '           / Object comment in the user catalogue.
# OBJSL28 = '        '           / Objects assigned to slit
# COMSL28 = '        '           / Object comment in the user catalogue.
# OBJSL29 = '        '           / Objects assigned to slit
# COMSL29 = '        '           / Object comment in the user catalogue.
# OBJSL30 = '        '           / Objects assigned to slit
# COMSL30 = '        '           / Object comment in the user catalogue.
# OBJSL31 = '        '           / Objects assigned to slit
# COMSL31 = '        '           / Object comment in the user catalogue.
# OBJSL32 = '        '           / Objects assigned to slit
# COMSL32 = '        '           / Object comment in the user catalogue.
# OBJSL33 = '        '           / Objects assigned to slit
# COMSL33 = '        '           / Object comment in the user catalogue.
# OBJSL34 = '        '           / Objects assigned to slit
# COMSL34 = '        '           / Object comment in the user catalogue.
# OBJSL35 = '        '           / Objects assigned to slit
# COMSL35 = '        '           / Object comment in the user catalogue.
# OBJSL36 = '        '           / Objects assigned to slit
# COMSL36 = '        '           / Object comment in the user catalogue.
# OBJSL37 = '        '           / Objects assigned to slit
# COMSL37 = '        '           / Object comment in the user catalogue.
# OBJSL38 = '        '           / Objects assigned to slit
# COMSL38 = '        '           / Object comment in the user catalogue.
# OBJSL39 = '        '           / Objects assigned to slit
# COMSL39 = '        '           / Object comment in the user catalogue.
# OBJSL40 = '        '           / Objects assigned to slit
# COMSL40 = '        '           / Object comment in the user catalogue.
# OBJSL41 = '        '           / Objects assigned to slit
# COMSL41 = '        '           / Object comment in the user catalogue.
# OBJSL42 = '        '           / Objects assigned to slit
# COMSL42 = '        '           / Object comment in the user catalogue.
# OBJSL43 = '        '           / Objects assigned to slit
# COMSL43 = '        '           / Object comment in the user catalogue.
# OBJSL44 = '        '           / Objects assigned to slit
# COMSL44 = '        '           / Object comment in the user catalogue.
# OBJSL45 = '        '           / Objects assigned to slit
# COMSL45 = '        '           / Object comment in the user catalogue.
# OBJSL46 = '        '           / Objects assigned to slit
# COMSL46 = '        '           / Object comment in the user catalogue.
# OBJSL47 = '        '           / Objects assigned to slit
# COMSL47 = '        '           / Object comment in the user catalogue.
# OBJSL48 = '        '           / Objects assigned to slit
# COMSL48 = '        '           / Object comment in the user catalogue.
# OBJSL49 = '        '           / Objects assigned to slit
# COMSL49 = '        '           / Object comment in the user catalogue.
# OBJSL50 = '        '           / Objects assigned to slit
# COMSL50 = '        '           / Object comment in the user catalogue.
# OBJSL51 = '        '           / Objects assigned to slit
# COMSL51 = '        '           / Object comment in the user catalogue.
# OBJSL52 = '        '           / Objects assigned to slit
# COMSL52 = '        '           / Object comment in the user catalogue.
# OBJSL53 = '        '           / Objects assigned to slit
# COMSL53 = '        '           / Object comment in the user catalogue.
# OBJSL54 = '        '           / Objects assigned to slit
# COMSL54 = '        '           / Object comment in the user catalogue.
# OBJSL55 = '        '           / Objects assigned to slit
# COMSL55 = '        '           / Object comment in the user catalogue.
# READMODE= 'CDS     '           / Detector readout mode in string
# EXPTIME =             9.999657 / Exposure time
# SECTIME =            11.054887 / Total time per sequence
# NOBSBLCK=                   13 / Requested blocks in the obs. sequence
# OBSBLOCK=                    1 / Counter of the block sequence
# NIMGOBBL=                    7 / Requested number of images per obs. block
# IMGOBBL =                    0 / Counter of the image sequence
# DRIFTCOR=                    T / Correction applied
# CYCLENUM= 'II      '           / Number of temperature cycle
# SKYADD  =                    T / Sky observed
# OBJRADIO=                  30. / Nodd throw radius for the dither pattern.
# NUM-NCOM=                   77
# UUID    = '6b156494-c4bc-11ea-a36f-000bab7913ae'
# NUM-BPM = 'tsutc:1465938031.42993'
# NUM-DK  = 'uuid:980d8943-9307-4a9b-9500-56347d753774'
# NUM-FF  = 'uuid:48328688-893a-11e8-9651-000bab7913ae'
# NUMXVER = '0.21.dev0-b9b03f6'  / Numina package version
# NUMRNAM = 'JoinDitheredImagesRecipe' / Numina recipe name
# NUMRVER =                    1 / Numina recipe version
# NUM-SK  = 'uuid:aaf7bc1a-c4bc-11ea-971c-000bab7913ae'
# COMMENT   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# COMMENT   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# COMMENT   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# COMMENT   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# COMMENT   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# COMMENT   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# COMMENT   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''  = '''''''''''''''''
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''Combined 2 images usi
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''Combination time 2020
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''Image uuid:6b156494-c
# HISTORY   = '  = ''  = ''''  = ''''''''  = ''''''''''''''''Image uuid:fe572066-c
# HISTORY   = '  = ''  = ''''  = ''''''''Combined 2 images using ''''''''''''''''m
# HISTORY   = '  = ''  = ''''  = ''''''''Combination time 2020-07-13T04:08:31.1867
# HISTORY   = '  = ''  = ''''  = ''''''''Image uuid:6b156494-c4bc-11ea-a36f-000bab
# HISTORY   = '  = ''  = ''''  = ''''''''Image uuid:41478078-c4be-11ea-a36f-000bab
# HISTORY   = '  = ''  = ''''Combined 2 images using ''''''''mean'''''''''''''''
# HISTORY   = '  = ''  = ''''Combination time 2020-07-13T04:10:24.461424'''''''
# HISTORY   = '  = ''  = ''''Image uuid:6b156494-c4bc-11ea-a36f-000bab7913ae''''''
# HISTORY   = '  = ''  = ''''Image uuid:8473a5d4-c4be-11ea-a36f-000bab7913ae''''''
# HISTORY   = '  = ''Combined 2 images using ''''mean'''''''
# HISTORY   = '  = ''Combination time 2020-07-13T04:12:20.338271'''
# HISTORY   = '  = ''Image uuid:6b156494-c4bc-11ea-a36f-000bab7913ae'''
# HISTORY   = '  = ''Image uuid:c7811cc6-c4be-11ea-a36f-000bab7913ae'''
# HISTORY   = 'Combined 2 images using ''mean'''
# HISTORY   = 'Combination time 2020-07-13T04:14:12.846623'
# HISTORY   = 'Image uuid:6b156494-c4bc-11ea-a36f-000bab7913ae'
# HISTORY   = 'Image uuid:0c548ed2-c4bf-11ea-a36f-000bab7913ae'

# %%
filehandle[0].header['FILTER']
# Out:
# 'J'

# %%
ww = WCS(filehandle[0].header)

# %%
# %matplotlib inline
import pylab as pl
from astropy import visualization
pl.style.use('dark_background')
# Out:
# In /orange/adamginsburg/miniconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /orange/adamginsburg/miniconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /orange/adamginsburg/miniconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /orange/adamginsburg/miniconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /orange/adamginsburg/miniconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /orange/adamginsburg/miniconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /orange/adamginsburg/miniconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /orange/adamginsburg/miniconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %%
# https://docs.astropy.org/en/stable/visualization/wcsaxes/
pl.figure(figsize=(12,12))
pl.subplot(projection=ww) # this line makes the image show up with RA/Dec coordinates
pl.imshow(filehandle[0].data,
          norm=visualization.simple_norm(filehandle[0].data, min_percent=1, max_percent=99.5))
